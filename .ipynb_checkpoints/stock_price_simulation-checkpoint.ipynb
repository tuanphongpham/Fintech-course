# %% [markdown]
# ### Instructor Demo: Stock Price Simulation
#
# This program executes a single simulation of stock price trajectory over the next `252` trading days (or year of trading) for `AAPL` stock, based on a normal probability distribution of historical average daily returns derived from the sample mean and standard deviation.

# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import alpaca_trade_api as tradeapi
# %matplotlib inline

# %%
# Load .env enviroment variables
from dotenv import load_dotenv
load_dotenv()

# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(alpaca_api_key, alpaca_secret_key, api_version='v2')

# %% [markdown]
# ### Check Available Tickers from Alpaca Markets API

# %%
# Get all Assets
assets = api.list_assets()

# Keep only tradeable assets
tradeable = [asset for asset in assets if asset.tradable ]
tradeable
# Out:
# [Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'bb05f61a-daf9-4fff-9e26-e0adaf23fbb0',
#      'marginable': True,
#      'name': 'HBT Financial, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HBT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '38b93a03-cd62-4158-acfc-78b0ef46da46',
#      'marginable': True,
#      'name': 'Franklin FTSE Hong Kong ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FLHK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'd3f264d8-99ca-4261-8a0b-98ef4534bcfd',
#      'marginable': True,
#      'name': 'Hennessy Capital Acquisition Corp. IV Unit',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HCACU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9522d758-7314-4ef6-8863-2976051c93a7',
#      'marginable': True,
#      'name': 'Harvest Capital Credit Corporation Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HCAP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '2035b2af-210a-4f47-9ed6-1d602019dc20',
#      'marginable': True,
#      'name': 'Warrior Met Coal, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HCC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '01b105aa-7e81-457c-a849-e2a6bb49ac6a',
#      'marginable': True,
#      'name': 'HL Acquisitions Corp. Right',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HCCHR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '86757f77-12ca-4dac-892e-b4e60ce4a382',
#      'marginable': True,
#      'name': 'AltShares Merger Arbitrage ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ARB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '49b90cdc-f6f5-4a7c-807a-ed172e6017af',
#      'marginable': True,
#      'name': 'American Express Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AXP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f85c0ede-3556-4d0b-9e0c-4ffc2425044d',
#      'marginable': True,
#      'name': 'Diageo plc',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'DEO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '65506476-2558-4092-a17b-5aa67bf14b2f',
#      'marginable': True,
#      'name': 'Document Security Systems, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DSS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'eac66d21-4d53-41da-8c38-644b6a49a28f',
#      'marginable': True,
#      'name': 'iShares Core High Dividend ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HDV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c886adde-83a4-42a7-a17a-b6db4f304374',
#      'marginable': True,
#      'name': 'Turtle Beach Corporation Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HEAR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '51286362-ddc2-4c58-9a74-692e082f3bbd',
#      'marginable': True,
#      'name': 'WisdomTree Europe Hedged Equity Fund',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HEDJ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'b43a6613-2ed0-4d67-b9f6-2fa4a1e6058e',
#      'marginable': False,
#      'name': 'Trend Aggregation Aggressive Growth ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TAAG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'e55e6f26-1083-4152-8a10-5c83effbc74a',
#      'marginable': False,
#      'name': 'Trend Aggregation U.S. ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TAEQ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '61f37453-eb13-494b-bfef-009fa69538b3',
#      'marginable': False,
#      'name': 'Trend Aggregation Dividend Stock ET',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TADS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'e4c66389-6072-4bb4-b481-f970cb1fe794',
#      'marginable': False,
#      'name': 'Trend Aggregation ESG ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TEGS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '698a0297-816c-43aa-8bfe-e4f7161bc11b',
#      'marginable': False,
#      'name': 'Kingsoft Cloud Holdings Limited American Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'KC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '97a6ff9a-6e4f-413a-af71-11c009818457',
#      'marginable': False,
#      'name': 'Aurora Cannabis Inc. Common Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ACB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'b9a198c4-54c4-43b1-b5c0-06bb45830776',
#      'marginable': False,
#      'name': 'Hudson Capital Inc. Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HUSN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '0553a09c-751c-46ed-83ce-57361f86393d',
#      'marginable': True,
#      'name': 'ICL Group Ltd.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ICL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '27155f8a-2e13-4098-a54b-d63ac819aa9c',
#      'marginable': True,
#      'name': 'Main Street Capital Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MAIN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': 'e95f17a7-1c02-4c04-b154-d681d76135fc',
#      'marginable': False,
#      'name': 'CTO Realty Growth, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CTO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '38515d47-7e61-4965-aa76-77ee2725b1cf',
#      'marginable': False,
#      'name': 'Ayala Pharmaceuticals, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AYLA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '5a5846b0-bd36-49bb-b680-d9077fa0023c',
#      'marginable': False,
#      'name': 'OceanFirst Financial Corp. Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'OCFCP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e431f452-8034-4a7f-b13b-0f3052723a95',
#      'marginable': False,
#      'name': 'China Liberal Education Holdings Limited Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CLEU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e1a1a555-c211-4949-84d9-a7aaa683fa1b',
#      'marginable': False,
#      'name': 'Cardiff Oncology, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CRDF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '2e91ded3-a6d8-423f-bbf0-e0a7f29b88ce',
#      'marginable': True,
#      'name': 'Twitter, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TWTR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'aada0990-b32c-4938-8359-02304e8e37fc',
#      'marginable': True,
#      'name': 'UFP Industries, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'UFPI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'adf623fb-f91a-4e45-aa66-6fb8f3677b23',
#      'marginable': True,
#      'name': 'United States Oil Fund, LP',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'USO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '2a5db6a2-c035-46cc-840f-fa519740a9b5',
#      'marginable': True,
#      'name': 'LifeSci Acquisition Corp. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'LSAC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f99ee8af-9d78-4b46-9f2c-3cf6ce839ccf',
#      'marginable': True,
#      'name': 'HCA Healthcare, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HCA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '94879939-21c2-4f40-a1a1-33b434a3f503',
#      'marginable': True,
#      'name': 'Harvest Capital Credit Corporation 6.125% Notes due 2022',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HCAPZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9f37ab1f-6877-4486-a021-749bdaa5b389',
#      'marginable': True,
#      'name': 'HL Acquisitions Corp. Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HCCH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'a2ca7b5b-365b-4d7a-937e-ff07bfdba43a',
#      'marginable': True,
#      'name': 'Hudson Technologies, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HDSN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd88d3dd6-14b6-460c-8dcf-f9a56f03bdcf',
#      'marginable': True,
#      'name': 'Hawaiian Electric Industries, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '6ba1ee01-181f-47cf-9683-fa0044f04793',
#      'marginable': True,
#      'name': 'American Financial Group, Inc. 6.000% Subordinated Debentures due '
#              '2055',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AFGH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '1fdc4268-268c-4e00-8795-44f32c6d0d9a',
#      'marginable': True,
#      'name': 'Hebron Technology Co., Ltd. Class A Common Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HEBT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'BATS',
#      'id': 'f8d51241-adc5-4b53-8ebe-80b357f27bed',
#      'marginable': True,
#      'name': 'iShares Currency Hedged MSCI Emerging Markets',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HEEM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c4db7980-480c-4097-97ad-3fe5287a0a81',
#      'marginable': True,
#      'name': 'American Finance Trust, Inc. 7.50% Series A Cumulative Redeemable '
#              'Perpetual Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AFINP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '613cb2a6-c53c-4895-a5a3-e8e4dd7d35ce',
#      'marginable': True,
#      'name': 'AgeX Therapeutics, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AGE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'f4bda675-e93b-4831-9d1e-d923fabb3e76',
#      'marginable': True,
#      'name': 'Federal Agricultural Mortgage Corporation 5.700% Non-Cumulative '
#              'Preferred Stock, Series D',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AGM-D',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '9bdade84-d6c8-4be1-aa0b-ebcb2715410e',
#      'marginable': True,
#      'name': 'Noble Energy Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'NBL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'f1ca0594-6570-4d09-af05-abda3a9958ed',
#      'marginable': True,
#      'name': 'Apache Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'APA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'bb2a26c0-4c77-4801-8afc-82e8142ac7b8',
#      'marginable': True,
#      'name': 'Netflix, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'NFLX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '36b5e4e5-50ad-431f-bf47-7c8836c8e3df',
#      'marginable': True,
#      'name': 'Gladstone Investment Corporation Business Development Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'GAIN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd052b90a-ec84-40f4-9ff3-1ad6a46a3f0a',
#      'marginable': True,
#      'name': 'Holly Energy Partners, L.P.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HEP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '48eb2a6f-8011-4699-baa1-d1ddec4d2e88',
#      'marginable': True,
#      'name': 'Pacer Funds Pacer Cash Cows Fund of Funds ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HERD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'a1a183c9-c792-4680-a521-2ebc9535a229',
#      'marginable': True,
#      'name': 'iShares Edge High Yield Defensive Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYDB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '68ab6a91-f696-4b18-a273-6303c43f5b2c',
#      'marginable': True,
#      'name': 'Ashford Hospitality Trust, Inc. 8.45% Series D',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AHT-D',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '1bb8e647-7556-488d-93fc-165973295ac0',
#      'marginable': True,
#      'name': 'VanEck Vectors Emerging Markets High Yield Bond ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HYEM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '77868d03-c43b-4fed-bc88-371e5ec5f088',
#      'marginable': True,
#      'name': 'iShares Interest Rate Hedged High Yield Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYGH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'fb08f28a-946e-4869-87da-faa2ff74d0e3',
#      'marginable': True,
#      'name': 'ProShares High Yield-Interest Rate Hedged ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYHG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '0bbed728-2fae-4524-b9d5-c7a8a6fd00a8',
#      'marginable': True,
#      'name': 'Xtrackers High Yield Corporate Bond - Interest Rate Hedged ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYIH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'ec7c49e0-d340-42f1-8573-59139d45e353',
#      'marginable': True,
#      'name': 'High Yield ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYLD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '690b38b4-0ceb-4367-ad97-4a6009575d21',
#      'marginable': True,
#      'name': 'SPDR Nuveen Bloomberg Barclays High Yield Municipal Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYMB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'f3ebb16e-9676-47e8-9cb8-d9b82fce081b',
#      'marginable': True,
#      'name': 'DFP Healthcare Acquisitions Corp. Class A Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DFPH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '8ba509c1-f49b-4ca0-be53-8094c9fd8e0f',
#      'marginable': True,
#      'name': 'Arlington Asset Investment Corp. 8.250% Series C '
#              'Fixed-to-Floating Rate Cumulative Redeemable Prefer',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AI-C',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '514b879a-7d3b-41ac-a5e5-c7f468175be2',
#      'marginable': True,
#      'name': 'HyreCar Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HYRE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '6ed4742e-c12b-408a-a340-f024e35b94ba',
#      'marginable': True,
#      'name': 'Horizon Therapeutics Public Limited Company Ordinary Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HZNP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': 'cfc4104f-db91-4fcd-adb1-01d6a6204837',
#      'marginable': True,
#      'name': 'Aberdeen Australia Equity Fund, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IAF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '1e5c82cd-5353-4632-8db3-a3cfa214267e',
#      'marginable': True,
#      'name': 'iShares Core International Aggregate Bond Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IAGG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'a8aa0b19-dc0d-4184-a9c4-c341fad9fda1',
#      'marginable': True,
#      'name': 'Griffin Industrial Realty, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'GRIF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'af3aaecb-69db-42bd-8946-34f445fd77bd',
#      'marginable': True,
#      'name': 'Inspire Corporate Bond Impact ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '17c4c384-f266-42a9-a7dc-c51ab1c07865',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2022 Term Corporate ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBDN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '461a3809-9238-44a6-942b-35524cc678fc',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2024 Term Corporate ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBDP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '5b5f63a7-ae37-447d-92ba-4d9f14a05fc9',
#      'marginable': True,
#      'name': 'AIkido Pharma Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AIKI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '75b5b1a6-7b48-434c-a2bb-28355a483760',
#      'marginable': True,
#      'name': 'Qraft AI-Enhanced US Large Cap Momentum ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AMOM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '69996024-6855-4a72-b36f-a477273ea0de',
#      'marginable': True,
#      'name': 'Andina Acquisition Corp. III Right',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ANDAR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'abcf9bcf-fbe9-432d-a982-dd541b32a826',
#      'marginable': True,
#      'name': 'VanEck Vectors Fallen Angel High Yield Bond',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ANGL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '87fe68f7-59ad-458e-bf18-9dd5c27f55b2',
#      'marginable': True,
#      'name': 'Anworth Mortgage Asset Corporation 6.25% Series B Preferred',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ANH-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': 'd99a209f-9648-4d14-a80a-121ce2c57672',
#      'marginable': True,
#      'name': 'Annovis Bio, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ANVS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '48dc6585-2e9e-498e-aafd-8a392ad5199e',
#      'marginable': True,
#      'name': 'iShares Core Aggressive Allocation ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AOA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'c5dbb3fb-2ea0-46a2-9d8c-6ffeed689e6f',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2027 Term Corporate ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBDS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'bd5a4768-2bb1-4a35-a6c7-f8b3defd6e8b',
#      'marginable': True,
#      'name': 'iShares iBonds 2021 Term High Yield and Income ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBHA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '70525328-1a21-4856-ac82-15391a0c480c',
#      'marginable': True,
#      'name': 'Harvard Bioscience, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HBIO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'dbd906c6-3c76-4047-8b14-ce8cb9ae2b83',
#      'marginable': True,
#      'name': 'Howard Bancorp, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HBMD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '16c539d5-447f-47b4-8725-3968d877622d',
#      'marginable': True,
#      'name': 'IBERIABANK Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IBKC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '6919782b-e865-47f2-bd98-4e216c2e8f98',
#      'marginable': True,
#      'name': 'IBERIABANK Corporation Depositary Shares Representing Series C '
#              'Fixed to Floating',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBKCO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'a2d428df-103b-4db0-b0b0-6d2c826b840c',
#      'marginable': True,
#      'name': 'Interactive Brokers Group, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IBKR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '355fc465-233c-49da-8967-f4ebb8566f67',
#      'marginable': True,
#      'name': 'Franklin Genomic Advancements ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HELX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'e0ede3fa-7eee-4303-9def-8b7ada764a4c',
#      'marginable': True,
#      'name': 'JOHN HANCOCK HEDGED EQUITY & INCOME FUND',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HEQ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '278ab94e-04a3-4d15-b00a-287535495939',
#      'marginable': True,
#      'name': 'Himax Technologies, Inc. American Depositary Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HIMX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '3e935d55-1356-4a24-91c3-f4e72f67c333',
#      'marginable': True,
#      'name': 'Xtrackers Low Beta High Yield Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYDW',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'c536e0b7-514e-4e48-8c10-5a8c6a8416db',
#      'marginable': True,
#      'name': 'iShares iBoxx $ High Yield Corporate Bond ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HYG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '0145318b-0a81-4e78-8667-14d81a60d91c',
#      'marginable': True,
#      'name': 'FlexShares High Yield Value-Scored Bond Index Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYGV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '7e88f506-bdb6-4dd5-be92-4e211136df56',
#      'marginable': True,
#      'name': 'Western Asset High Yield Defined Opportunity Fund Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'af950aa9-aa4d-4cdc-a318-bff7aab478fd',
#      'marginable': True,
#      'name': 'Xtrackers USD High Yield Corporate Bond ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HYLB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '822d3109-af90-4ea1-b970-af1c6f4b4101',
#      'marginable': True,
#      'name': 'AGM Group Holdings Inc. Class A Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AGMH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '8426dfcd-ab54-4c12-9a01-80f8f1509467',
#      'marginable': True,
#      'name': 'IQ S&P High Yield Low Volatility Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYLV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '2957dd8a-a916-4d0a-a2dd-8e6a7587522a',
#      'marginable': True,
#      'name': 'WisdomTree Trust WisdomTree WisdomTree Negative Duration High '
#              'Yield Bond Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYND',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '2f6547cf-dafc-4255-9f58-33c7ea30d726',
#      'marginable': True,
#      'name': 'CP High Yield Trend ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYTR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c59d3b30-7990-49f4-84b8-f09e128955b0',
#      'marginable': True,
#      'name': 'Gladstone Capital Corporation 5.375% Notes due 2024',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GLADL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'c016f4da-3079-47b4-9caa-453e7462e9a7',
#      'marginable': True,
#      'name': 'Ashford Hospitality Trust, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AHT-F',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '2a11a750-c54a-4cc8-a564-1a487771b4e8',
#      'marginable': True,
#      'name': 'iShares Global ex USD High Yield Corporate Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYXU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '23bf6719-1838-4d6c-99a5-768db1766189',
#      'marginable': True,
#      'name': 'WisdomTree Trust WisdomTree Interest Rate Hedged High Yield Bond '
#              'Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYZD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '10df661b-bf88-4a66-8c64-d00d6381df8d',
#      'marginable': True,
#      'name': 'Aesthetic Medical International Holdings Group Ltd. American '
#              'Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AIH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f5067d1a-a4b3-4617-a3f4-cf609b630d28',
#      'marginable': True,
#      'name': 'VOYA ASIA PACIFIC HIGH DIVIDEND EQUITY INCOME FUND',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IAE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '0d76a428-e812-424f-a5a1-48a040c173e6',
#      'marginable': True,
#      'name': 'AllianzGI Artificial Intelligence & Technology Opportunities Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AIO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '150eccc9-d174-41cc-8ec3-0184d37a95d9',
#      'marginable': True,
#      'name': 'IAMGold Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IAG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'b9af90cb-83b0-4ede-b11c-d7584ebcac41',
#      'marginable': True,
#      'name': 'iShares U.S. Broker-Dealers & Securities Exchanges ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IAI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '3e0d60d8-8bde-46f6-8ebf-3950efe109ba',
#      'marginable': True,
#      'name': 'Integra LifeSciences Holdings Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IART',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '1fd25ac1-a90f-4130-915b-2407da832050',
#      'marginable': True,
#      'name': 'Anchiano Therapeutics Ltd. American Depositary Share',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ANCN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '6772db3e-f28f-45bd-905e-8a294354b5b9',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2020 Term Corporate ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IBDL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '2750d3d5-db29-43d5-a044-b0eccc8665b3',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2021 Term Corporate ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IBDM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'bf1940a7-37e3-4aee-b427-a50cd304b275',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2023 Term Corporate ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBDO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '3fa87a42-9771-4815-bdb8-bd1ab4d8de6c',
#      'marginable': True,
#      'name': 'Andina Acquisition Corp. III Unit',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ANDAU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '7d46f4fb-d202-42f6-b8ac-9b36e5c4b1ec',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2026 Term Corporate ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBDR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '104939cf-ff9b-462b-899d-03d9419cf875',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2029 Term Corporate ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBDU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'eeb5dcb3-50eb-4721-90bb-bcef09449b29',
#      'marginable': True,
#      'name': 'Hudbay Minerals Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HBM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '28d52448-0af8-4c2a-9d33-39a57485e973',
#      'marginable': True,
#      'name': 'iBio, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBIO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '87d97bdf-5628-4ad0-9035-d89b453eb1ee',
#      'marginable': True,
#      'name': 'IBERIABANK Corporation Depositary Shares 6.10% Fixed-to-Floating '
#              'Non-Cumulative Perpetual Preferred Stock, Series D',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IBKCN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'ea2c713a-dc84-4269-b354-3c49bf3c7ec5',
#      'marginable': True,
#      'name': 'IBERIABANK Corporation Depositary Shares Representing Series B '
#              'Fixed to Floating',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBKCP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '1ccc517b-0360-492e-8770-2b4a27be0cd7',
#      'marginable': True,
#      'name': 'iShares iBonds Sep 2020 Term Muni Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBMI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'f9fe3bfd-264f-4c23-ad84-596cd2895f6a',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2022 Term Muni Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBMK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '72fedbe5-5e57-4e0d-b45c-d0b1292367f9',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2024 Term Muni Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBMM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '00b64222-8748-4ea5-861f-69e98e4c0f66',
#      'marginable': True,
#      'name': 'iShares Trust iShares iBonds Dec 2021 Term Treasury ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBTA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '441dee37-5d26-4c24-b6af-56c87841da47',
#      'marginable': True,
#      'name': 'Anworth Mortgage Asset Corp 8.625% Ser A Pfd',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ANH-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9fc56485-8d32-413c-9886-cdf2c504a3da',
#      'marginable': True,
#      'name': 'AirNet Technology Inc. American Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ANTE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'da66f273-55f1-4fe4-aac2-0e84b95c4d3e',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2021 Term Muni Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBMJ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '09577f1c-4e97-4e37-aa87-e01541f1147a',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2023 Term Muni Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBML',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '122f3148-83e7-4419-8cea-ce9fb62fa44d',
#      'marginable': True,
#      'name': 'iShares iBonds Dec 2025 Term Muni Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBMN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'a8b4dec1-56c4-4e91-9d6d-12ef6686dbef',
#      'marginable': True,
#      'name': 'INSTALLED BUILDING PRODUCTS, INC.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IBP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '8f705a3f-8711-4b95-a4d0-f99c4d450005',
#      'marginable': True,
#      'name': 'iShares Trust iShares iBonds Dec 2022 Term Treasury ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBTB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e9acabb4-a4c2-45e7-bc57-58968954c906',
#      'marginable': True,
#      'name': 'iShares Trust iShares iBonds Dec 2024 Term Treasury ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBTE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c7cfbc8d-df5f-4685-a47c-e33be69490f6',
#      'marginable': True,
#      'name': 'iShares Trust iShares iBonds Dec 2027 Term Treasury ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBTH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'af5a0872-3867-489f-beb9-3b86865570dc',
#      'marginable': True,
#      'name': 'Independent Bank Group, Inc Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IBTX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '72c27004-6461-441e-9dba-5e136a70f3ab',
#      'marginable': True,
#      'name': 'County Bancorp, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ICBK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '1725a8ba-c019-46db-8a58-c8b314292f34',
#      'marginable': True,
#      'name': 'ICC Holdings, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ICCH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'c1496c7d-df89-471a-93b1-22bb668d04fd',
#      'marginable': True,
#      'name': 'Principal Investment Grade Corporate Active ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'ab474c46-89fd-4d69-b9e0-62a1a4da9760',
#      'marginable': True,
#      'name': 'iShares Interest Rate Hedged Long-Term Corporate Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IGBH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'BATS',
#      'id': 'f889b6ba-0e76-42cf-af46-734f1ee52a4a',
#      'marginable': True,
#      'name': 'ProShares Investment Grade-Interest Rate Hedged',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IGHG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'aef76cf6-b8d7-4cff-8ab1-72311d7e2a66',
#      'marginable': True,
#      'name': 'iShares Intermediate-Term Corporate Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IGIB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '930ad0ce-921d-41a7-b0a0-799b3c831a61',
#      'marginable': True,
#      'name': 'iShares Long-Term Corporate Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IGLB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '3dc99e27-0c8e-48e0-a0c8-cb726aa845fa',
#      'marginable': True,
#      'name': 'IGM Biosciences, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IGMS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '059c4266-c71a-4c96-b7d4-a53bf7ecedff',
#      'marginable': True,
#      'name': 'VOYA EMERGING MARKETS HIGH INCOME DIVIDEND EQUITY FUND',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IHD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'b6363520-5e1e-4b1d-9921-2d5ae013f01b',
#      'marginable': True,
#      'name': 'iShares U.S. Pharmaceuticals ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IHE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'f912d405-d0dd-49ec-99ff-60a8f6e1983f',
#      'marginable': True,
#      'name': 'InterContinental Hotels Group Plc',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IHG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '6ad2cd44-2b93-4bea-aa4e-934d7873e815',
#      'marginable': True,
#      'name': 'Invesco High Income 2023 Target Term Fund Common Shares of '
#              'Beneficial Interest, No par value per sha',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IHIT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '91981b8f-2490-431b-84ab-3e16a1c3ae01',
#      'marginable': True,
#      'name': 'InnSuites Hospitality Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IHT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'b1336b62-0381-414d-a6ea-809e7814f3ec',
#      'marginable': True,
#      'name': 'VanEck Vectors International High Yield Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IHY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '537d20af-4f4a-4586-be31-a547d3dad788',
#      'marginable': True,
#      'name': 'Morgan Stanley India Investment Fund, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IIF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '22e64cf8-33b7-4b0f-873a-e3f761f7d4ab',
#      'marginable': True,
#      'name': 'Information Services Group, Inc. Information Services Group Inc. '
#              'Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'III',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'ae995c81-adcc-452d-b35c-7f8b1709da8d',
#      'marginable': True,
#      'name': 'i3 Verticals, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IIIV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '38e3bac7-2ec1-4308-bd32-90ce9943012e',
#      'marginable': True,
#      'name': 'Intricon Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IIN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'da2c8645-d9de-40d9-9341-d36ed8c9657f',
#      'marginable': True,
#      'name': 'iMedia Brands, Inc. Class A Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IMBI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': '40cd693a-74da-4f0e-a8f5-bc5b172b1677',
#      'marginable': True,
#      'name': 'Impac Mortgage Holdings Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IMH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '780d3252-39b1-453d-9ef6-cae23150474b',
#      'marginable': True,
#      'name': 'Immutep Limited American Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IMMP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c8e8ffb6-2cf2-4788-bf32-99f6ccb021b6',
# ...
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '1d040c95-eed6-47ae-8512-e73afbdc29d5',
#      'marginable': True,
#      'name': 'M.D.C. Holdings, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MDC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'a76fa46d-d68d-4423-905e-fbb35128062d',
#      'marginable': True,
#      'name': 'Medigus Ltd. American Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MDGS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '8410aa86-0bdc-4d03-99e1-f31d388b2a36',
#      'marginable': True,
#      'name': 'First Trust Exchange-Traded Fund VI Multi-Asset Diversified '
#              'Income Index Fund',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MDIV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'a56556fd-c695-46c4-a27b-f9ddd812dd3d',
#      'marginable': True,
#      'name': 'Medley LLC 7.25% Notes due 2024',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MDLQ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '1aadfd32-9407-4cdf-8e83-f486b439ea3c',
#      'marginable': True,
#      'name': 'Medley Management Inc',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MDLY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'fee6d449-30b4-456b-8cf8-d14c9f192729',
#      'marginable': True,
#      'name': 'Meredith Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MDP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'a55dcd28-50dc-4831-8a25-ee97bd91f16e',
#      'marginable': True,
#      'name': 'Acacia Communications, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACIA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd3b26730-a352-406c-95a7-502a8b1c40bc',
#      'marginable': True,
#      'name': 'Aecom',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ACM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'f1723d3c-bbba-4bc7-a1c4-8cd035c03eb5',
#      'marginable': True,
#      'name': 'AMCI Acquisition Corp. Unit',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AMCIU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e537fc6f-fe8b-4003-927c-872f6749a7ea',
#      'marginable': True,
#      'name': 'Medalist Diversified REIT, Inc. Series A Cumulative Redeemable '
#              'Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MDRRP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '6db93524-f41a-413b-8819-16b3c31f70ed',
#      'marginable': True,
#      'name': 'CNO Financial Group, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CNO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '2f36446e-2dbb-47e0-aaac-38ecb5c30850',
#      'marginable': True,
#      'name': 'SPDR S&P Kensho Clean Power ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CNRG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c219946f-3c86-43ed-9b8a-d636133f9c8e',
#      'marginable': True,
#      'name': 'CNS Pharmaceuticals, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CNSP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '044e016d-4b8f-4656-b903-c66b102023b0',
#      'marginable': True,
#      'name': 'CNX Resources Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CNX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'f23b79f5-283b-4acf-81e3-b039ea45e7f3',
#      'marginable': True,
#      'name': 'iShares MSCI China A ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CNYA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '103efcce-0e17-4e4e-bc12-9e5352144ef0',
#      'marginable': True,
#      'name': 'Coda Octopus Group, Inc. Common stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CODA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '949922e8-b577-4d30-832e-a825ab3366e5',
#      'marginable': True,
#      'name': 'Matsons, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MATX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '22a9af4c-eecc-4fc2-a9c7-a8a52efa9528',
#      'marginable': True,
#      'name': 'Pioneer Municipal High Income Advantage Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MAV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '5aaa8179-23da-4b31-8f31-711a2c58b7e5',
#      'marginable': True,
#      'name': 'iShares MBS ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MBB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '2af09fdf-12be-4106-b69e-6f4cce4d6d55',
#      'marginable': True,
#      'name': 'Marrone Bio Innovations, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MBII',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '24fa8176-7754-4ed7-a5d7-12d14986b3ba',
#      'marginable': True,
#      'name': 'Merchants Bancorp Depositary Shares Each Representing a 1/40th '
#              'Interest in a Share of Series B  Fixed-to-Floating Rate',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MBINO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '7285ad49-6c2d-4f35-bdf9-2c9bbabbef71',
#      'marginable': True,
#      'name': 'Mustang Bio, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MBIO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'b3a1d607-aa62-4509-9456-23579f287b95',
#      'marginable': True,
#      'name': 'Moleculin Biotech, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MBRX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '875eeaba-d3bc-417e-981b-61048257a4ba',
#      'marginable': True,
#      'name': 'Mobile Telesystems PJSC',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MBT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '4b8662bc-f1f6-4958-a69b-b4310a3bcb1d',
#      'marginable': True,
#      'name': 'Mercantile Bank Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MBWM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'ea808fd1-5fc9-4469-8381-bdbca956175c',
#      'marginable': True,
#      'name': 'Metropolitan Bank Holding Corp. Common Stock, $0.01 par value per '
#              'share',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MCB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '38c3ac8f-3cfe-4445-ada9-12ced351f727',
#      'marginable': True,
#      'name': 'MetroCity Bankshares, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MCBS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'e077638f-a5c9-47e4-a7ce-2bfabf5ff698',
#      'marginable': True,
#      'name': "McDonald's Corporation",
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MCD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '7f76a717-fc5a-4662-a389-85ede913b3c1',
#      'marginable': True,
#      'name': 'Contango Oil & Gas Co.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MCF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'edc751a9-e628-40bd-9498-23ad7918269e',
#      'marginable': True,
#      'name': 'Microchip Technology Incorporated Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MCHP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '19303380-7930-4280-bffe-b8add2a9c67a',
#      'marginable': True,
#      'name': 'Barings Corporate Investors',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MCI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'e530d022-86a4-4f70-98a3-2c33ef892e4d',
#      'marginable': True,
#      'name': 'Madison Covered Call & Equity Strategy Fund',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MCN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'e8024508-76ce-4bb7-80f5-062c220eeaf7',
#      'marginable': True,
#      'name': 'MFS Charter Income Trust Shares of Beneficial Interest',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MCR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'bac0c94e-42af-44c3-b60a-ede8f7342a8d',
#      'marginable': True,
#      'name': 'Monarch Casino & Resort, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MCRI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '8c18cb44-861a-4aac-be16-60ba18fe7551',
#      'marginable': True,
#      'name': 'IQ Hedge Macro Tracker',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MCRO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '4484782c-13b8-4aa2-b6d2-4749a0d10d0f',
#      'marginable': True,
#      'name': 'MEDLEY CAPITAL CORPORATION 6.125%  SENIOR NOTES DUE 2023',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MCV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '1f42101a-e67c-4930-9673-af331ab04d8f',
#      'marginable': True,
#      'name': 'Mednax, Inc (Holding Company)',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '7556ca4d-fe04-4a24-aebc-57857390efcb',
#      'marginable': True,
#      'name': 'Madrigal Pharmaceuticals, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MDGL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'abc8f93b-8f15-4018-b86a-c98b2d1dca4c',
#      'marginable': True,
#      'name': 'Mediaco Holding Inc. Class A Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MDIA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '0951485e-fdac-491b-8cc2-67ea543c5f7c',
#      'marginable': True,
#      'name': 'Medallia, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MDLA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '64b565c7-458d-4ad8-96e0-b3316c396e90',
#      'marginable': True,
#      'name': 'Medley LLC  6.875% Senior Notes due 2026',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MDLX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '705ec4dc-73b9-42fc-8b17-d4e13c31cfae',
#      'marginable': True,
#      'name': 'Mondelez International, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MDLZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '4da1a0f0-a031-498a-a4b3-dba5fd991a34',
#      'marginable': True,
#      'name': 'Medalist Diversified REIT, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MDRR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'e66886ce-8f75-4661-b4d2-68e1521013b8',
#      'marginable': True,
#      'name': 'CNX Midstream Partners LP',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CNXM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c92d1f60-f836-4fe0-84c9-e1788feebb23',
#      'marginable': True,
#      'name': 'Cocrystal Pharma, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'COCP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '447bdd9b-1457-4227-a5f9-00e7f2ff7fe8',
#      'marginable': True,
#      'name': 'Compass Diversified Holdings Shares of Beneficial Interest',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CODI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '8df729b2-2345-460d-809c-59f6c7980c17',
#      'marginable': True,
#      'name': 'Allscripts Healthcare Solutions, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MDRX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '149fc17e-513c-430c-b328-8ad219db5a9b',
#      'marginable': True,
#      'name': 'SPDR S&P 400 Mid Cap Value ETF (based on S&P MidCap 400 Value '
#              'Index--symbol: MGD)',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MDYV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '9da5a0a9-95c3-4286-8c42-faba906383df',
#      'marginable': True,
#      'name': 'Compass Diversified Holdings 7.875% Series B Fixed-to-Floating '
#              'Rate Cumulative Preferred Shares repr',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CODI-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '23b2320f-55ee-4ee1-ae5e-99552d5b7247',
#      'marginable': True,
#      'name': 'Capital One Financial Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'COF-F',
#      'tradable': True}),
#  ...]

# %%
# Create a new empty DataFrame
asset_info_df = pd.DataFrame()
asset_info_df['symbol'] = pd.Series([asset.symbol for asset in assets])

# Display the first 10 asset tickers
display(asset_info_df.head(10))
# Out:
#   symbol
# 0    HBT
# 1   FLHK
# 2  HCACU
# 3   HCAP
# 4    HCC
# 5  HCCHR
# 6    ARB
# 7    AXP
# 8    DEO
# 9    DSS

# %% [markdown]
# ### Get 1 Year's Worth of Data via API Call and Read in as DataFrame

# %%
# Set the ticker
ticker = "AAPL"

# Set timeframe to '1D'
timeframe = '1D'

# Set start and end datetimes of 1 year, between now and 365 days ago.
start_date = pd.Timestamp("2019-05-04", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2020-05-04", tz="America/New_York").isoformat()

# Get 1 year's worth of historical data for AAPL
df = api.get_barset(
    ticker,
    timeframe,
    limit=None,
    start=start_date,
    end=end_date,
    after=None,
    until=None,
).df

df.head()
# Out:
#                               AAPL
#                               open      high      low   close    volume
# 2019-05-06 00:00:00-04:00  204.290  208.8400  203.500  208.60  28949691
# 2019-05-07 00:00:00-04:00  205.880  207.4175  200.825  202.86  34328425
# 2019-05-08 00:00:00-04:00  201.900  205.3400  201.750  202.90  22729670
# 2019-05-09 00:00:00-04:00  200.400  201.6800  196.660  200.72  32427147
# 2019-05-10 00:00:00-04:00  197.419  198.8500  192.770  197.30  36118438

# %% [markdown]
# ### Drop Extraneous Levels and Columns

# %%
# Drop Outer Table Level
df = df.droplevel(axis=1, level=0)

# Use the drop function to drop extra columns
df.drop(columns=['open', 'high', 'low', 'volume'], inplace=True)

# Since this is daily data, we can keep only the date (remove the time) component of the data
df.index = df.index.date

df.head()
# Out:
#              close
# 2019-05-06  208.60
# 2019-05-07  202.86
# 2019-05-08  202.90
# 2019-05-09  200.72
# 2019-05-10  197.30

# %% [markdown]
# ### Calculate Daily Returns

# %%
# Use the `pct_change` function to calculate daily returns of AAPL
daily_returns = df.pct_change()
daily_returns.head()
# Out:
#                close
# 2019-05-06       NaN
# 2019-05-07 -0.027517
# 2019-05-08  0.000197
# 2019-05-09 -0.010744
# 2019-05-10 -0.017039

# %% [markdown]
# ### Calculate Value of Average Daily Returns

# %%
# Use the `mean` function to calculate the mean of daily returns for AAPL
avg_daily_return = daily_returns.mean()['close']
avg_daily_return
# Out:
# 0.001693341594111356

# %% [markdown]
# ### Calculate Value of Standard Deviation of Daily Returns

# %%
# Use the `std` function to calculate the standard deviation of daily returns for AAPL
std_dev_daily_return = daily_returns.std()['close']
std_dev_daily_return
# Out:
# 0.025944544825252065

# %% [markdown]
# ### Run the Monte Carlo Simulation and Save Results to DataFrame

# %%
# Set number of trading days and get last closing price of AAPL from DataFrame
num_trading_days = 252
aapl_last_price = df['close'][-1]

# Initialize the simulated prices list with the last closing price of AAPL
simulated_aapl_prices = [aapl_last_price]

# Simulate the returns for 252 days
for i in range(num_trading_days):
    # Calculate the simulated price using the last price within the list
    simulated_price = simulated_aapl_prices[-1] * (1 + np.random.normal(avg_daily_return, std_dev_daily_return))
    # Append the simulated price to the list
    simulated_aapl_prices.append(simulated_price)
    
# Create a DataFrame of the simulated prices
simulated_price_df = pd.DataFrame({
    "Simulated AAPL Prices": simulated_aapl_prices
})

# Print head of DataFrame
simulated_price_df.head()
# Out:
#    Simulated AAPL Prices
# 0             293.170000
# 1             291.371871
# 2             289.534864
# 3             286.955816
# 4             295.753527

# %% [markdown]
# ### Plot the Simulated Stock Price Trajectory for AAPL over the Next Year (252 Trading Days)

# %%
# Use the `plot` function to plot the trajectory of AAPL stock based on a 252 trading day simulation
simulated_price_df.plot()

# %% [markdown]
# ### Calculate Daily Returns of Simulated Stock Prices for AAPL

# %%
# Use the `pct_change` function to calculate daily returns of simulated stock prices for AAPL
simulated_daily_returns = simulated_price_df.pct_change()
simulated_daily_returns.head()
# Out:
#    Simulated AAPL Prices
# 0                    NaN
# 1              -0.006133
# 2              -0.006305
# 3              -0.008908
# 4               0.030659

# %% [markdown]
# ### Calculate the Cumulative Returns of Simulated Stock Prices for AAPL

# %%
# Use the `cumprod` function to calculate the cumulative returns of simulated stock prices for AAPL
simulated_cumulative_returns = (1 + simulated_daily_returns).cumprod()
simulated_cumulative_returns.head()
# Out:
#    Simulated AAPL Prices
# 0                    NaN
# 1               0.993867
# 2               0.987601
# 3               0.978803
# 4               1.008812

# %% [markdown]
# ### Calculate the Cumulative Profits/Losses of Simulated Stock Prices for AAPL

# %%
# Multiply an initial investment by the cumulative returns of simulative stock prices to
# return the progression of cumulative returns in terms of money
initial_investment = 10000
cumulative_pnl = initial_investment * simulated_cumulative_returns
cumulative_pnl.head()
# Out:
#    Simulated AAPL Prices
# 0                    NaN
# 1            9938.666011
# 2            9876.005852
# 3            9788.034809
# 4           10088.123855

# %% [markdown]
# ### Plot the Cumulative Profits/Losses of `$10,000` in AAPL Over the Next `252` Trading Days

# %%
# Use the 'plot' function to create a chart of the cumulative profits/losses
cumulative_pnl.plot()
